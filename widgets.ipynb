# %%
from __future__ import print_function, division, unicode_literals, absolute_import

import sys
import os

# %matplotlib notebook
from IPython.display import display

import df_widgets.pandasw as pdw
import df_widgets.seabornw as snw

import seaborn as sns
iris = sns.load_dataset("iris")

# %%
pdw.dfw_plot(iris)
# Out:
# <img src="data:image/png;base64,...">

# %%
snw.pairplot(iris)
# Out:
# <img src="data:image/png;base64,...">

# %%
titanic = sns.load_dataset("titanic")

# %%
snw.countplot(titanic)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/gmatteo/git/df_widgets/df_widgets/seabornw.py in countplot(x, y, hue, color, saturation)
#      14
#      15     def countplot(x, y, hue, color, saturation):
# ---> 16         x, y, hue = ut.widget2py(x, y, hue, color)
#      17         ax, fig, _ = ut.get_ax_fig_plt()
#      18         sns.countplot(x=x, y=y, hue=hue, data=df, order=None, hue_order=None, orient=None,
#
# ValueError: too many values to unpack

# %%
tips = sns.load_dataset("tips")

# %%
snw.joinplot(tips)

# %%
snw.swarmplot(tips)
